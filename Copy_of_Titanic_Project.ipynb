# %% [markdown]
# # Titanic Dataset Analysis Project

# %% [markdown]
# ## Instruction
# Steps to do the project-assignment:
# 1. Click on the .ipynb file
# 2. Open with Google Colab / Jupyter Notebook
# 3. Make a copy of it
# 4. Do the Project
# 5. After completion share your .ipynb file in *Editor*  mode only

# %% [markdown]
# ## Table Structure

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The above picture shows the column names of the dataset. You will find the dataset in your Google Classroom.
#
#
# 1.   Survived : Survived from titanic
# 2.   Pclass : Passenger Class
# 3.   sex : Male/Female
# 4.   age : Numeric value
# 5.   sibsp : Number of Siblings/Spouses Aboard.
# 6.   parch : Number of Parents/Children Aboard.
# 7.   fare : Ticket Price(numeric)
# 8.   embarked : destination code
# 9.   class : categorical object version of Pclass
# 10.  Who : Well defined Person type
# 11.  adult_male : only Adult male
# 12.  deck : Deck under Pclass
# 13.  embark_town : destination town

# %% [markdown]
# ### Load the dataset

# %%
#Write your code here
import os
import pandas as pd
df=pd.read_csv('/content/titanic.csv - titanic.csv.csv - titanic.csv - titanic.csv.csv.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town
# ...

# %% [markdown]
# ### Find out the information about the dataset

# %%
#Write your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
# dtypes: bool(1), float64(2), int64(4), object(6)
# memory usage: 84.5+ KB

# %% [markdown]
# ### Make a shallow copy and use the shallow copy further

# %%
#Write your code
s_cpy=df.copy(deep=False)
s_cpy
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town
# ...

# %% [markdown]
# ### Find the total no of missing value and fill the missing value respectively

# %%
#Write your code here
df.isnull().sum().sum()
# Out:
# 869

# %%
#Write your code here
df.fillna(value=3)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   3.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town
# ...

# %% [markdown]
# ### Find unique values, if Datatype changing required, change it

# %%
import numpy as np
print(np.unique(df['sex']))
# Out:
# ['female' 'male']

# %%
df.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# Alive           object
# dtype: object

# %%
df['pclass']=df['pclass'].astype(float)

# %%
df.dtypes
# Out:
# survived         int64
# pclass         float64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# Alive           object
# dtype: object

# %% [markdown]
# ### Make a new column **Alive** and set the value True or False depending upon **Survived** column

# %%
df.loc[df['survived']>=1,"Alive"]="True"
df.loc[df['survived']<=0,"Alive"]="False"
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town  Alive
# ...

# %% [markdown]
# ### Make a new column **Alone** and set the value True or False depending upon **Sibsp and Parch** columns

# %%
#Write your code here
df.loc[df['parch']>=1,"Alone"]="True"
df.loc[df['sibsp']<=0,"Alone"]="False"
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0     3.0    male  22.0      1      0   7.2500        S   Third
# 1           1     1.0  female  38.0      1      0  71.2833        C   First
# 2           1     3.0  female  26.0      0      0   7.9250        S   Third
# 3           1     1.0  female  35.0      1      0  53.1000        S   First
# 4           0     3.0    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0     2.0    male  27.0      0      0  13.0000        S  Second
# 887         1     1.0  female  19.0      0      0  30.0000        S   First
# 888         0     3.0  female   NaN      1      2  23.4500        S   Third
# 889         1     1.0    male  26.0      0      0  30.0000        C   First
# 890         0     3.0    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town  Alive  Alone
# ...

# %% [markdown]
# ### Find the counts of all categorical columns

# %%
#Write your code here
print(df.age.value_counts())
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: age, Length: 88, dtype: int64

# %% [markdown]
# ### Find the correlation between columns and plot the correlation in Heatmap

# %%
#Write your code here

cor=df.corr()
cor
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
#
#             adult_male
# survived     -0.557080
# pclass        0.094035
# age           0.280328
# sibsp        -0.253586
# parch        -0.349943
# fare         -0.182024
# adult_male    1.000000

# %%
#write your code here
import seaborn as sns
sns.heatmap(cor.corr())

# %% [markdown]
# ### Plot countplot for **Sex** column

# %%
#Write your code here
sns.countplot(x='sex',data=df)

# %% [markdown]
# ### Make a histogram for Age column

# %%
#Write your code here
import matplotlib.pyplot as plt
plt.hist(df['age'],color='red',edgecolor='white')


plt.title("Histogram plot")
plt.show()

# %% [markdown]
# ### Make a Scatter plot for **Age vs Survived** column
# **After plotting, write a note, what do you think about the graph**

# %%
#Write your code here
plt.scatter(df['age'],df['survived'], c='green')
plt.title('scatter plot of age vs survived')
plt.xlabel('age')
plt.ylabel('survived')
plt.show()

# %% [markdown]
# **Double tap in it, then Write your answer**
# age is horizontal to x axis and survived is perpendicular to y axis.

# %% [markdown]
# ### Make a violin plot where x axis=class and y axis=survived and plot with respect to sex column
#
# **After plotting, write a note, what do you think about the graph**

# %%
#Write your code here
sns.violinplot(x='class',y='survived',data=df)

# %% [markdown]
# **Double tap in it, then Write your answer**
# first class people are more survived.

# %% [markdown]
# ### Make countplot for **Who** Column

# %%
#Write your code
sns.countplot(x='who',data=df)

# %% [markdown]
# ### Make a countplot for **Embark_town** column and write where the maximum people were going

# %%
#Write your code here
sns.countplot(x='embark_town',data=df)

# %% [markdown]
# **Double click and Write here**
#
# > Indented block
#
#
# southampton people are maximum going

# %% [markdown]
# ### Make violinplot for **Who vs survived** Column

# %%
#Write your code here
sns.violinplot(x="who",y="survived",data=df)

# %% [markdown]
# ### Make a statistical table for all columns

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# Make a Box Plot of Age column

# %%
#Write your code here
sns.boxplot(y=df['age'])
